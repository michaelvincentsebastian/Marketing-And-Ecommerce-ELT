# %%
import duckdb

# %%
con = duckdb.connect()

# %%
dbPath = 'db.db'

# %%
con.sql(f"ATTACH '{dbPath}' as db;")

# %%
con.sql("SHOW ALL TABLES;")
# Out:
# ┌──────────┬──────────────────────────┬────────────────────────────────────────────────┬───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┬───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┬───────────┐
# │ database │          schema          │                      name                      │                                                                                                             column_names                                                                                                              │                                                             column_types                                                              │ temporary │
# ...

# %%
con.sql("SELECT * FROM db.sqlmesh_example__dev.full_model;")
# Out:
# ┌─────────┬────────────┐
# │ item_id │ num_orders │
# │  int32  │   int64    │
# ├─────────┼────────────┤
# │       1 │          5 │
# │       2 │          1 │
# │       3 │          1 │
# └─────────┴────────────┘

# %%
con.sql("SELECT * FROM db.sqlmesh_example__dev.seed_model;")
# Out:
# ┌───────┬─────────┬────────────┐
# │  id   │ item_id │ event_date │
# │ int32 │  int32  │    date    │
# ├───────┼─────────┼────────────┤
# │     1 │       2 │ 2020-01-01 │
# │     2 │       1 │ 2020-01-01 │
# │     3 │       3 │ 2020-01-03 │
# │     4 │       1 │ 2020-01-04 │
# │     5 │       1 │ 2020-01-05 │
# │     6 │       1 │ 2020-01-06 │
# │     7 │       1 │ 2020-01-07 │
# └───────┴─────────┴────────────┘

# %%
con.sql("SELECT * FROM db.sqlmesh_example__dev.incremental_model;")
# Out:
# ┌───────┬─────────┬────────────┐
# │  id   │ item_id │ event_date │
# │ int32 │  int32  │    date    │
# ├───────┼─────────┼────────────┤
# │     1 │       2 │ 2020-01-01 │
# │     2 │       1 │ 2020-01-01 │
# │     3 │       3 │ 2020-01-03 │
# │     4 │       1 │ 2020-01-04 │
# │     5 │       1 │ 2020-01-05 │
# │     6 │       1 │ 2020-01-06 │
# │     7 │       1 │ 2020-01-07 │
# └───────┴─────────┴────────────┘
